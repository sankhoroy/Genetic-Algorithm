# %%
# !pip install numpy

# %%
# !pip install matplotlib

# %%
from config import *
from population import population
from chromosome import chromosome
from gene import gene

circle = [(39, 0),(51, 58), (30, 58), (10, 25), (69, 24), (20, 7), (66, 44),(59, 7),(14, 46)]
random_points = [(73, -94), (25, 73),(-98, 22),(-50, -43),(16, 46),(16, 13),(-27, -71),(-13, -23),(58, -81),(-75, 43),(95, -86),(-43, -70),(44, 45), (-19, -94),(-37, 45),(-59, 12),(33, -26),(-58, 85),(92, -97)]
random_points_2 = [(49, 19),(87, -69),(29, 45),(-50, 56),(-66, -33),(22, -33),(27, -72),(82, 61),(97, 33),(58, 18),(-9, -19),(50, 58),(-38, 67),(98, 3)]

if __name__ == '__main__':
# input is x 
    x = random_points
    #plotting initial 
    starting_population = population(x)
    starting_chromosome = chromosome([starting_population])
    starting_distance = starting_population._totaldistance()
    starting_chromosome._plot_chromosome_tour()
    
    #Applying Genetic Algorithm
    g = gene(x)
    
    #plotting best
    final_best_population = g.overall_best
    final_best_chromosome = chromosome([final_best_population])
    final_best_distance = final_best_population._totaldistance()
    final_best_chromosome._plot_chromosome_tour()
    print('================== Results of Optimization ============================')
    print('Initial Distance : ', starting_distance)
    print('Optimized final Distance :', final_best_distance)
    print(((starting_distance - final_best_distance)*100/starting_distance),'% distance reduced')
# Out:
# average fitness of generation : 0.004999999999999994
# generation no :  1
# average fitness of generation : 0.004999999999999991
# generation no :  2
# average fitness of generation : 0.00499999999999998
# generation no :  3
# average fitness of generation : 0.004999999999999981
# generation no :  4
# average fitness of generation : 0.005000000000000013
# generation no :  5
# average fitness of generation : 0.00500000000000002
# generation no :  6
# average fitness of generation : 0.005000000000000009
# generation no :  7
# average fitness of generation : 0.00500000000000001
# generation no :  8
# average fitness of generation : 0.005000000000000009
# generation no :  9
# average fitness of generation : 0.004999999999999987
# generation no :  10
# average fitness of generation : 0.004999999999999982
# generation no :  11
# average fitness of generation : 0.004999999999999981
# generation no :  12
# average fitness of generation : 0.00499999999999998
# generation no :  13
# average fitness of generation : 0.004999999999999987
# generation no :  14
# average fitness of generation : 0.004999999999999984
# generation no :  15
# average fitness of generation : 0.004999999999999993
# generation no :  16
# average fitness of generation : 0.004999999999999991
# generation no :  17
# average fitness of generation : 0.00500000000000001
# generation no :  18
# average fitness of generation : 0.004999999999999993
# generation no :  19
# average fitness of generation : 0.004999999999999993
# generation no :  20
# average fitness of generation : 0.004999999999999992
# generation no :  21
# average fitness of generation : 0.00499999999999999
# generation no :  22
# average fitness of generation : 0.004999999999999991
# generation no :  23
# average fitness of generation : 0.00499999999999999
# generation no :  24
# average fitness of generation : 0.004999999999999985
# generation no :  25
# average fitness of generation : 0.004999999999999986
# generation no :  26
# average fitness of generation : 0.004999999999999987
# generation no :  27
# average fitness of generation : 0.004999999999999986
# generation no :  28
# average fitness of generation : 0.004999999999999985
# generation no :  29
# average fitness of generation : 0.0049999999999999845
# generation no :  30
# average fitness of generation : 0.00499999999999998
# generation no :  31
# average fitness of generation : 0.0049999999999999776
# generation no :  32
# average fitness of generation : 0.004999999999999978
# generation no :  33
# average fitness of generation : 0.004999999999999977
# generation no :  34
# average fitness of generation : 0.004999999999999978
# generation no :  35
# average fitness of generation : 0.004999999999999979
# generation no :  36
# average fitness of generation : 0.004999999999999978
# generation no :  37
# average fitness of generation : 0.004999999999999978
# generation no :  38
# average fitness of generation : 0.004999999999999979
# generation no :  39
# average fitness of generation : 0.004999999999999978
# generation no :  40
# average fitness of generation : 0.00499999999999998
# generation no :  41
# average fitness of generation : 0.004999999999999979
# generation no :  42
# average fitness of generation : 0.00499999999999998
# generation no :  43
# average fitness of generation : 0.00499999999999998
# generation no :  44
# average fitness of generation : 0.004999999999999979
# generation no :  45
# average fitness of generation : 0.004999999999999978
# generation no :  46
# average fitness of generation : 0.004999999999999982
# generation no :  47
# average fitness of generation : 0.004999999999999981
# generation no :  48
# average fitness of generation : 0.004999999999999979
# generation no :  49
# average fitness of generation : 0.004999999999999979
# generation no :  50
# average fitness of generation : 0.004999999999999978
# ================== Results of Optimization ============================
# Initial Distance :  2257.2838407680747
# Optimized final Distance : 763.3692714730901
# 66.18195471539184 % distance reduced
